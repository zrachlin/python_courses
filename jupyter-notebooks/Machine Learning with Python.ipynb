# %% [markdown]
# # Introduction to Jupyter
#
# ### Keyboard shortcuts
#
# - Pres Esc key to enable / disable
# - Executing cells - Esc, Shft-Enter OR Ctrl-Enter
# - Adding a cell above Esc, A
# - Adding a cell below - Esc, B
# - Delete a cell - Esc, D, D
# - Copy, Cut, Paste - Ctrl-C, Ctrl-X, Ctrl-V
# - Undo - Ctrl-Z
# - Select all - Ctrl-A
# - Comment Cell - Ctrl-/

# %% [markdown]
# # Machine Learning Overview
#
# John fill in this outline with what you want to talk about

# %% [markdown]
# # Managing Packages
# This is a review from the Data Analysis with Python Course
#
# ### PyPi
# - PyPi is the index of publicly available packages
# - https://pypi.org/
#
# ### Pip
# - Check if pip is installed
#     1. Open a command prompt (Windows) or terminal (Mac)
#     2. Type 'python -V'
#     3. Type 'pip -V'
# - pip is the tool used for managing packages in Python
# - Installed with python3
# - Install all packages that are not a part of standard python library
# - https://pypi.org/project/pip/
#
# ### Package we will use in this course
# - numpy, matplotlib, pandas, sklearn
# - Check what packages are installed with help("modules")
# - Install packages from the command line
#     1. Open a command prompt (Windows) or Terminal (Mac)
#     2. Type 'pip install <package-name>' (ex. pip install pandas, pip install matplotlib)
#
# ### Importing packages
# - use import statement to allow your code to use a package

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Python Packages for Data Science
#
# - SciKit Learn - https://scikit-learn.org/stable/

# %% [markdown]
# # Importing Data
#
# ### From a Database
#
# 1. MySQL (mysql.connector)
# 2. SQL Server / Sybase (pymssql)
# 3. DB2 (ibm_db)
# 4. PostgreSQL (psycopg2)
# 5. MongoDB / Other NoSQL databases (pymongo)
#
# ### From a file into NumPy Array
# import numpy as np
# csv = np.genfromtxt ('file.csv', delimiter=",")
#
# ### From Scikit Learn
# from sklearn.datasets import load_iris
# iris = load_iris()

# %%
from sklearn.datasets import load_iris
iris = load_iris()

x = iris['data']
y = iris['target']
df = pd.DataFrame(x, columns = iris['feature_names'])

# %% [markdown]
# # Explore the Data

# %%
# Explore the data
df.head()

# %%
# What is the shape of the data?
df.shape

# %% [markdown]
# # Splitting Data into Training and Test Data

# %%
# Split into training and test datasets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %% [markdown]
# # Feature Scaling
#
# ### Plot the data before and after scaling

# %%
# Plot distribution sepal_length training data
sns.set()
sepal_length_train_before=pd.Series(x_train[:,1], name="sepal length training")
ax=sns.distplot(sepal_length_train_before)

# %%
# Plot the test data sepal_length before
sns.set()
sepal_length_test_before=pd.Series(x_test[:,1], name="sepal length test")
ax=sns.distplot(sepal_length_test_before)

# %%
# Plot distribution sepal_width training data
sns.set()
sepal_width_train_before=pd.Series(x_train[:,2], name="sepal width training")
ax=sns.distplot(sepal_width_train_before)

# %%
# Plot distribution sepal_width test data
sns.set()
sepal_width_test_before=pd.Series(x_test[:,2], name="sepal width test")
ax=sns.distplot(sepal_width_test_before)

# %%
# Plot distribution petal_length training data
sns.set()
pedal_length_train_before=pd.Series(x_train[:,3], name="petal length training")
ax=sns.distplot(pedal_length_train_before)

# %%
# Plot distribution petal_length test data
sns.set()
pedal_length_test_before=pd.Series(x_test[:,3], name="petal length test")
ax=sns.distplot(pedal_length_train_before)

# %%
# Plot distribution of petal_width training data
# Type your answer here:

# %%
# Plot distribution of petal_width test data
# Type your answer here:

# %%
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()  
scaler.fit(x_train)

x_train_scaled = scaler.transform(x_train)  
x_test_scaled = scaler.transform(x_test)

# %%
# Plot distribution of sepal length training data
sns.set()
sepal_length_train_scaled=pd.Series(x_train_scaled[:,1], name="sepal length training")
ax=sns.distplot(sepal_length_train_scaled)

# %%
# Plot distribution of sepal length test data
sns.set()
sepal_length_test_scaled=pd.Series(x_test_scaled[:,1], name="sepal length test")
ax=sns.distplot(sepal_length_test_scaled)

# %%
# Plot distribution of sepal width training data
sns.set()
sepal_width_train_scaled=pd.Series(x_train_scaled[:,2], name="sepal width training")
ax=sns.distplot(sepal_width_train_scaled)

# %%
# Plot distribution of sepal width test data
sns.set()
sepal_width_test_scaled=pd.Series(x_test_scaled[:,2], name="sepal width test")
ax=sns.distplot(sepal_width_test_scaled)

# %%
# Plot test and training distributions for petal width and length here
# Type your answer here (4 plots):

# %% [markdown]
# # Training and Predictions

# %%
# Train the data
from sklearn.neighbors import KNeighborsClassifier  
classifier = KNeighborsClassifier(n_neighbors=5)  
classifier.fit(x_train, y_train)

# %%
# Make predictions
y_pred = classifier.predict(x_test)
print(y_pred)

# %% [markdown]
# # Evaluating the Algorithm
#
# ### Common Metrics for Evalutaion
# - confusion matrix
# - precision
# - recall
# - f1 score

# %%
from sklearn.metrics import classification_report, confusion_matrix  
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
results = classification_report(y_test, y_pred)
print(results)

# %% [markdown]
# # Other Plots

# %%
# Plot a scatterplot matrix
sns.set()
sns.pairplot(data=df,kind='scatter')

# %% [markdown]
# # Export Your Script
#
# File -> Download As -> Python (.py)
